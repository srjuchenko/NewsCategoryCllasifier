# %%
import time
import bs4
from bs4 import BeautifulSoup  
import pandas as pd
import scipy as sc
import numpy as np
import requests
from datetime import date

# --- selenium libraries
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# %%
                                                    #chromedriver.exe for windows users!
def get_infinity_page_html_data(chromedriver_path="./chromedriver.exe", scroll_number=1, sleep_time=3):
    # Create selenium driver
    s = Service(chromedriver_path)
    driver = webdriver.Chrome(service=s)    
    driver.get(url)
    
    for i in range(1,scroll_number):
        print(f"scroll_number: {i}")
        driver.execute_script("window.scrollTo(1,50000)")
        time.sleep(sleep_time)
    html_data = driver.page_source
    driver.close()
    
    return html_data

# %%
def extract_medium_articles_from_HTML_data(html_data):
    # Extract articles from HTML data 
    soup = BeautifulSoup(html_data, 'html.parser')    
    articles = soup.find_all("article")
    print(f"Number of articles: {len(articles)}")
    
    return articles

# %%
def create_df_from_articles(articles,category):    
    # Create a lists for df
    categories = []
    headers = []
    contents = []
    for article in articles:
        headers.append(article.find("h2").get_text()) 
        categories.append(category)
        
        if category == "politics" or category == "food":
            content = article.find("p", {"class": lambda L: L and L.startswith('lj b do dp')})        
        if category == "sports" or category == "technology" or category == "weather":
            content = article.find("p", {"class": lambda L: L and L.startswith('lf b do dp')})
        if category == "entertainment":
            content = article.find("p", {"class": lambda L: L and L.startswith('lg b do dp')})
        if category == "business" or category == "science":
            content = article.find("p", {"class": lambda L: L and L.startswith('li b do dp')})
        
        if content is not None:
            contents.append(content.get_text())
        else:
            contents.append(content)
        
        
        
    return pd.DataFrame(
        {"category": categories,  
         "header": headers,
         "content": contents})

# %% [markdown]
# main crawling function

# %%
#here you can add more categories
#sports, technology, politics, entertiment, business, weather, food, science ... 
categories = ["technology", "politics", "sports", "entertainment", "weather", "science", "business", "food"]

for category in categories: 
    #medium
    url = f"https://medium.com/tag/{category}"
    html_data = get_infinity_page_html_data(scroll_number=10)
    articles = extract_medium_articles_from_HTML_data(html_data)
    df = create_df_from_articles(articles, category)
    print(df.shape)
    print(df)
    df.to_csv(f"./csv_files/medium_{category}_{date.today()}.csv")
# Out:
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 98
# (98, 3)
#       category                                             header content
# 0   technology            The CurseForge Official API is Now Live    None
# 1   technology           Stop Creating UI Components From Scratch    None
# 2   technology  Terra LUNA and UST- Deep Dive Into the Terra R...    None
# 3   technology  What Does It Mean To Be A “Good-Faith Skeptic”...    None
# 4   technology                          From KamiLimu to Big Tech    None
# ..         ...                                                ...     ...
# 93  technology                          Why I left Amazon… (PIP?)    None
# 94  technology  Research Papers on developments in Edge Comput...    None
# 95  technology      Hybrid Work Week Just Don’t Work For Everyone    None
# 96  technology  iOS 15.5 RC is Out! — And It’s Most Likely The...    None
# 97  technology  Homeowners, Help is Here: Announcing the First...    None
#
# [98 rows x 3 columns]
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 100
# (100, 3)
#     category                                             header content
# 0   politics  Azov commander upholds soldiers’ lives as Russ...    None
# 1   politics  Americans Need to Wake Up. Their Society is Im...    None
# 2   politics  Those Who Push Replacement Theory Are to Blame...    None
# 3   politics                          Revolution, Ready or Not.    None
# 4   politics  A Coup to Remove Putin is Underway and it’s Un...    None
# ..       ...                                                ...     ...
# 95  politics  Meet the Man Who Almost Killed Hitler and Ende...    None
# 96  politics         Who is new Prime Minister Élisabeth Borne?    None
# 97  politics  The Buffalo Shooting, Replacement Theory, and ...    None
# 98  politics                     On Resisting the Outside World    None
# 99  politics  The Ominous Rise of “Constitutional Republic” ...    None
#
# [100 rows x 3 columns]
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: