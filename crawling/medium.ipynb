# %%
import time
import bs4
from bs4 import BeautifulSoup  
import pandas as pd
import scipy as sc
import numpy as np
import requests
from datetime import date

# --- selenium libraries
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# %%
                                                    #chromedriver.exe for windows users!
def get_infinity_page_html_data(chromedriver_path="./chromedriver.exe", scroll_number=1, sleep_time=3):
    # Create selenium driver
    s = Service(chromedriver_path)
    driver = webdriver.Chrome(service=s)    
    driver.get(url)
    
    for i in range(1,scroll_number):
        print(f"scroll_number: {i}")
        driver.execute_script("window.scrollTo(1,50000)")
        time.sleep(sleep_time)
    html_data = driver.page_source
    driver.close()
    
    return html_data

# %%
def extract_medium_articles_from_HTML_data(html_data):
    # Extract articles from HTML data 
    soup = BeautifulSoup(html_data, 'html.parser')    
    articles = soup.find_all("article")
    print(f"Number of articles: {len(articles)}")
    
    return articles

# %%
def create_df_from_articles(articles,category):    
    # Create a lists for df
    categories = []
    headers = []
    contents = []
    for article in articles:
        headers.append(article.find("h2").get_text()) 
        categories.append(category)
        
        if category == "politics" or category == "food":
            content = article.find("p", {"class": lambda L: L and L.startswith('lj b do dp')})        
        if category == "sports" or category == "technology" or category == "weather":
            content = article.find("p", {"class": lambda L: L and L.startswith('lf b do dp')})
        if category == "entertainment":
            content = article.find("p", {"class": lambda L: L and L.startswith('lg b do dp')})
        if category == "business" or category == "science":
            content = article.find("p", {"class": lambda L: L and L.startswith('li b do dp')})
        
        if content is not None:
            contents.append(content.get_text())
        else:
            contents.append(content)
        
        
        
    return pd.DataFrame(
        {"category": categories,  
         "header": headers,
         "content": contents})

# %% [markdown]
# main crawling function

# %%
#here you can add more categories
#sports, technology, politics, entertiment, business, weather, food, science ... 
categories = ["technology", "politics", "sports", "entertainment", "weather", "science", "business", "food"]

for category in categories: 
    #medium
    url = f"https://medium.com/tag/{category}"
    html_data = get_infinity_page_html_data(scroll_number=10)
    articles = extract_medium_articles_from_HTML_data(html_data)
    df = create_df_from_articles(articles, category)
    print(df.shape)
    print(df)
    df.to_csv(f"./csv_files/medium_{category}_{date.today()}.csv")
# Out:
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 100
# (100, 3)
#       category                                             header content
# 0   technology  Self-Driving Car Hits Robot Dog — JavaScript’s...    None
# 1   technology           The Highly Misunderstood Segway Disaster    None
# 2   technology   JavaScript Concepts Every Programmer Should Know    None
# 3   technology  Observability Pt. 1: ทำความรู้จักกับ Observabi...    None
# 4   technology       Top 5 Browser Extensions for Data Scientists    None
# ..         ...                                                ...     ...
# 95  technology  Tech Up for Change: It’s Time For Innovators t...    None
# 96  technology     Clicking Suspicious Links? Better Think Twice!    None
# 97  technology                   Why are Developers Stressed Out?    None
# 98  technology  SimpleHold Partners with FIO Protocol to Make ...    None
# 99  technology                       Mac Studio First Impressions    None
#
# [100 rows x 3 columns]
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 100
# (100, 3)
#     category                                             header content
# 0   politics                             Sympathy for the Devil    None
# 1   politics    What Do You Call the Feeling of a Dying Planet?    None
# 2   politics  How this Became the Age of the Dumb, Toxic Bas...    None
# 3   politics  Solarpunk Wants to Change the World — What Is It?    None
# 4   politics  The Age of Extinction Is Here — Some of Us Jus...    None
# ..       ...                                                ...     ...
# 95  politics                                            Really?    None
# 96  politics              How to Muck Up Everything, Optimally!    None
# 97  politics  America has Two Parties but it doesn’t need to...    None
# 98  politics  He Went From ‘The Sheriff of Wall Street’ to T...    None
# 99  politics  Captain America: The Winter Solider — A Tribut...    None
#
# [100 rows x 3 columns]
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: