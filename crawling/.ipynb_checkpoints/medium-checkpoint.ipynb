# %%
import time
import bs4
from bs4 import BeautifulSoup  
import pandas as pd
import scipy as sc
import numpy as np
import requests
from datetime import date

# --- selenium libraries
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# %%
                                                    #chromedriver.exe for windows users!
def get_infinity_page_html_data(chromedriver_path="./chromedriver", scroll_number=1, sleep_time=3):
    # Create selenium driver
    s = Service(chromedriver_path)
    driver = webdriver.Chrome(service=s)    
    driver.get(url)
    
    for i in range(1,scroll_number):
        print(f"scroll_number: {i}")
        driver.execute_script("window.scrollTo(1,50000)")
        time.sleep(sleep_time)
    html_data = driver.page_source
    driver.close()
    
    return html_data

# %%
def extract_medium_articles_from_HTML_data(html_data):
    # Extract articles from HTML data 
    soup = BeautifulSoup(html_data, 'html.parser')    
    articles = soup.find_all("article")
    print(f"Number of articles: {len(articles)}")
    
    return articles

# %%
def create_df_from_articles(articles,category):    
    # Create a lists for df
    categories = []
    headers = []
    contents = []
    for article in articles:
        headers.append(article.find("h2").get_text()) 
        categories.append(category)
        
        if category == "politics" or category == "food":
            content = article.find("p", {"class": lambda L: L and L.startswith('lj b do dp')})        
        if category == "sports" or category == "technology" or category == "weather":
            content = article.find("p", {"class": lambda L: L and L.startswith('lf b do dp')})
        if category == "entertainment":
            content = article.find("p", {"class": lambda L: L and L.startswith('lg b do dp')})
        if category == "business" or category == "science":
            content = article.find("p", {"class": lambda L: L and L.startswith('li b do dp')})
        
        if content is not None:
            contents.append(content.get_text())
        else:
            contents.append(content)
        
        
        
    return pd.DataFrame(
        {"category": categories,  
         "header": headers,
         "content": contents})

# %% [markdown]
# main crawling function

# %%
#here you can add more categories
#sports, technology, politics, entertiment, business, weather, food, science ... 
categories = ["technology", "politics", "sports", "entertainment", "weather", "science", "business", "food"]

for category in categories: 
    #medium
    url = f"https://medium.com/tag/{category}"
    html_data = get_infinity_page_html_data(scroll_number=10)
    articles = extract_medium_articles_from_HTML_data(html_data)
    df = create_df_from_articles(articles, category)
    print(df.shape)
    print(df)
    df.to_csv(f"./csv_files/medium_{category}_{date.today()}.csv")
# Out:
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 128
# (128, 3)
#        category                                             header  \
# 0    technology  6 Lessons Learned from Selling My Side Project...
# 1    technology        Factions, Orders and the Great Seeker Clans
# 2    technology               Understanding the Irrationality of π
# 3    technology  4 Apps That Will Make You More Productive as a...
# 4    technology     We’re Uncovering One of AI’s Deepest Mysteries
# ..          ...                                                ...
# 123  technology  Patreon Vs Buy Me a Coffee Vs Fanvue: The Diff...
# 124  technology                             May 2022 Twosletter ✌️
# 125  technology  How Netflix lost $50Billion and How going to t...
# 126  technology                               I Hate My Smartphone
# 127  technology                1 Side Hustle for up to $10,000/gig
#
#                                                content
# 0    The story of how I acquired an abandoned side ...
# 1    Bringing Seekers closer together… —  With some...
# 2    An indescribably beautiful proof —  In this ar...
# 3    Become more productive when writing code, taki...
# 4    The black box problem is a secret between mach...
# ..                                                 ...
# 123  What is the difference between Patreon Vs Buy ...
# 124  May 2022 Twosletter - Twos\nTwos: The best pla...
# 125  Netflix has lost upwards of 35% of its stock w...
# 126  I’ve written a bit before about how my relatio...
# 127  One valuable side hustle to meet your financia...
#
# [128 rows x 3 columns]
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles:
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 125
# (125, 3)
#     category                                             header  \
# 0    science  Why Banning Abortion is Terrible For Public He...
# 1    science   The Secrets of Tesla’s and Ramanujan’s Knowledge
# 2    science               Understanding the Irrationality of π
# 3    science  The Introduction to String Theory You Were Loo...
# 4    science        Web3 is about to disrupt scientific funding
# ..       ...                                                ...
# 120  science                Mark Sargent: The Flat Earth Pusher
# 121  science                              Origin of our reality
# 122  science  Can Amazon’s Project Kuiper Compete With Starl...
# 123  science                                       There’s Hope
# 124  science         What no one tells you about getting a Ph.D
#
#                                                content
# 0    Dispelling myths about abortion —  Abortion is...
# 1    What do the two eccentric geniuses have in com...
# 2    An indescribably beautiful proof —  In this ar...
# 3    What you need to know about string theory and ...
# 4    Science. For some, it catalyzes memories of mi...
# ..                                                 ...
# 120  If Mark Can Explain the Conundrum in this Arti...
# 121  Once upon a time in February, 2050 in a small ...
# 122  The billionaire space race is hotting up. —  S...
# 123  By Dave Wegner “There’s Hope.” Two words spoke...
# 124  So you’re going back to school, congratulation...
#
# [125 rows x 3 columns]
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 129
# (129, 3)
#      category                                             header  \
# 0    business  10 Beautiful Productivity App Concepts You’d W...
# 1    business         The 7 Habits Of Insanely Prolific Creators
# 2    business  How Does Notion Help Me to Organize My Entire ...
# 3    business  A strategic design approach to brand transform...
# 4    business  Her Startup Raised $3 Million, Then It All Sta...
# ..        ...                                                ...
# 124  business  Hanif Joshaghani Of Symend On The Five Things ...
# 125  business  The Book “MANIFESTING MADE EASY: A Retrospecti...
# 126  business  How to Swing Trade like a Pro: 8 Strategies th...
# 127  business       7 Insights That Can Make You A Better Leader
# 128  business  The Great Resignation & The Future Of Work: Ya...
#
#                                                content
# 0    The most stunning productivity software you’ve...
# 1    Some of the greatest creators were people like...
# 2    Notion makes devilishly complex problems seem ...
# 3    “Brand transformation” can mean 1,000 things. ...
# 4    How 15 Minutes and One Word Prevented a Founde...
# ..                                                 ...
# 124  An Interview With Sara Connell —  Work through...
# 125  CONTENTS OF THE BOOK Introduction: A Chaos The...
# 126  The key to trading success. —  Swing trading i...
# 127  Management is hard. You’ve just enough power t...
# 128  An Interview with Karen Mangia —  Creating a p...
#
# [129 rows x 3 columns]
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# scroll_number: 4
# scroll_number: 5
# scroll_number: 6
# scroll_number: 7
# scroll_number: 8
# scroll_number: 9
# Number of articles: 129
# (129, 3)
#     category                                             header  \
# 0       food  Dietary Nitrates Are Bad, Right? It’s Complica...
# 1       food  What to eat in Spain? TOP 5 dishes you must tr...
# 2       food         Famous Politicians as Pretentious Desserts
# 3       food    Grow Your own Food & Build Stronger Communities
# 4       food  How to keep and store your Rice fresh for deca...
# ..       ...                                                ...
# 124     food  Eating Our Way to Extinction Review From a Foo...
# 125     food                  Marketing is a brainwash machine.
# 126     food                          The Publican — Location 5
# 127     food    9 Foods That Can Make You Look 10 Years Younger
# 128     food  How empty buildings can be utilized and moneti...
#
#                                                content
# 0    FIRST, I AM NOT GOING TO PROCLAIM THAT nobody ...
# 1    If you are planning a trip to Spain, it is wor...
# 2    Try the Rick Santorum — Cream horns topped wit...
# 3    Grow Your own Food & Build Stronger Communitie...
# 4    Inexpensive. It’s simple to put together. Calo...
# ..                                                 ...
# 124  Last Friday was Earth Day. The one day each ye...
# 125  Do you know the power of marketing and promoti...
# 126  This is a continuation of The Great Chicago Oy...
# 127  According to science. —  Lotions, masks, cream...
# 128  It’s been a little over two years since the pa...
#
# [129 rows x 3 columns]
